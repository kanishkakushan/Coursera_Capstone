# %% [markdown]
# # Cousera Capstone Project: Find the Similar Neighbourhood to live in

# %% [markdown]
# Supose you have got a better Job and to join that you have to leave your current place and move to a location near to your office. So you want to find the same or similar type of neighbourhood in the new location to live in. This is the main concept behind this project. Below code is to fullfill the requirement of the assignment of week 1.

# %%
import pandas as pd
import numpy as np
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
